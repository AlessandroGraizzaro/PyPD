# %%
import ipywidgets as widgets

# %%
widgets.IntSlider()

# %%
from IPython.display import display
w = widgets.IntSlider()
display(w)

# %%
display(w)

# %%
w.value
# Out:
# 0

# %%
w.value = 100

# %%
widgets.Text(value='Hello World!', disabled=True)

# %%
a = widgets.FloatText()
b = widgets.FloatSlider()
display(a,b)

mylink = widgets.jslink((a, 'value'), (b, 'value'))

# %% [markdown]
# ## Trying some things out

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from ipywidgets import interact

# %%
def func(x, a, b):
    return a*x + b

# %%
x_in = np.linspace(-10,10,20)

plt.plot(x_in, func(x_in, 3, 3), label='A=3, B=3')
plt.grid(True)
plt.legend(loc=2)
plt.xlabel('x')
plt.ylabel('y')

# %%
def plot_new(a, b):
    x = np.linspace(-10,10,20)
    plt.plot(x_in, func(x_in, 3, 3), label='A=3, B=3')
    plt.grid(True)
    plt.legend(loc=2)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.plot(x, func(x, a, b), 'r-', label='Generated Line')
    plt.xlim([-10, 10])
    plt.ylim([-40, 40])

interact(plot_new, a=(1, 10), b=(1, 10))

# %%
interact(plot_new, a=widgets.BoundedFloatText(value=3, Description='a'), b=widgets.BoundedFloatText(value=3, Description='b'))
